# %%
# Importing Libraries

import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# Reading the Dataset

dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Converting the nominal data to numeric data

dataset = pd.get_dummies(dataset, drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# Getting the column names

dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# Splitting the dataset into input and output variables

independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#Importing GridSearchCv and RandomForestRegressor to create the best model 

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion' :['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
              'max_features' : [None, 'sqrt', 'log2'], 'n_estimators' : [10,25,50,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1 )
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Users\reema\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 25, 50, 100]},
#              verbose=3)

# %%
# Printing the best model from the grid

re = grid.cv_results_

print("The R_Score for Best parameter is {} : ".format(grid.best_params_))
# Out:
# The R_Score for Best parameter is {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100} :

# %%
# getting all the grid values in table format

table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.241619      0.119554         0.043982        0.050527
# 1        0.338250      0.101524         0.015083        0.002806
# 2        0.417308      0.031783         0.021206        0.006177
# 3        0.904524      0.016113         0.021833        0.012122
# 4        0.078448      0.009839         0.004157        0.006304
# 5        0.211220      0.043269         0.010836        0.003261
# 6        0.264823      0.010358         0.011745        0.010520
# 7        0.629016      0.025465         0.018504        0.006617
# 8        0.064938      0.007494         0.005807        0.001120
# 9        0.195663      0.008601         0.004234        0.003565
# 10       0.297452      0.023196         0.013914        0.002716
# 11       0.528448      0.010952         0.016304        0.002329
# 12       0.099134      0.011392         0.006316        0.007057
# 13       0.208427      0.014435         0.008233        0.006951
# 14       0.396214      0.029073         0.013003        0.002214
# 15       0.853237      0.028783         0.021121        0.006878
# 16       0.091198      0.013120         0.008785        0.007033
# 17       0.161093      0.023453         0.014945        0.008832
# 18       0.270131      0.009894         0.009879        0.008118
# 19       0.611000      0.068941         0.038807        0.025874
# 20       0.091076      0.041434         0.009476        0.007740
# 21       0.183163      0.034553         0.011800        0.007986
# 22       0.305057      0.020845         0.009156        0.007487
# 23       0.529487      0.009444         0.021591        0.006959
# 24       0.255391      0.007046         0.005401        0.006319
# 25       0.702100      0.056110         0.018675        0.013959
# 26       1.495001      0.193162         0.028088        0.014452
# 27       3.491885      0.131342         0.034210        0.011717
# 28       0.309566      0.070403         0.020067        0.024416
# 29       0.478128      0.086690         0.011018        0.006006
# 30       0.865788      0.122295         0.016759        0.010697
# 31       1.879304      0.275647         0.060197        0.030245
# 32       0.185630      0.021055         0.003125        0.006250
# 33       0.533522      0.147831         0.043541        0.063348
# 34       1.418190      0.121486         0.019764        0.011528
# 35       3.269996      0.042165         0.051640        0.018672
# 36       0.226312      0.033031         0.008711        0.005732
# 37       0.690964      0.142665         0.023614        0.021486
# 38       0.839940      0.051977         0.027768        0.010731
# 39       1.519268      0.058304         0.032048        0.006182
# 40       0.117982      0.016365         0.011730        0.011739
# 41       0.273233      0.017090         0.012066        0.006416
# 42       0.512360      0.046905         0.022609        0.007951
# 43       1.000245      0.030920         0.040108        0.006583
# 44       0.109392      0.008751         0.003467        0.004255
# 45       0.248343      0.018285         0.008805        0.010553
# 46       0.550305      0.033341         0.026829        0.005716
# 47       0.923753      0.058810         0.017334        0.003418
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 10
# 1    squared_error               None                 25
# 2    squared_error               None                 50
# 3    squared_error               None                100
# 4    squared_error               sqrt                 10
# 5    squared_error               sqrt                 25
# 6    squared_error               sqrt                 50
# 7    squared_error               sqrt                100
# 8    squared_error               log2                 10
# 9    squared_error               log2                 25
# 10   squared_error               log2                 50
# 11   squared_error               log2                100
# 12    friedman_mse               None                 10
# 13    friedman_mse               None                 25
# 14    friedman_mse               None                 50
# 15    friedman_mse               None                100
# 16    friedman_mse               sqrt                 10
# 17    friedman_mse               sqrt                 25
# 18    friedman_mse               sqrt                 50
# 19    friedman_mse               sqrt                100
# 20    friedman_mse               log2                 10
# 21    friedman_mse               log2                 25
# 22    friedman_mse               log2                 50
# 23    friedman_mse               log2                100
# 24  absolute_error               None                 10
# 25  absolute_error               None                 25
# 26  absolute_error               None                 50
# 27  absolute_error               None                100
# 28  absolute_error               sqrt                 10
# 29  absolute_error               sqrt                 25
# 30  absolute_error               sqrt                 50
# 31  absolute_error               sqrt                100
# 32  absolute_error               log2                 10
# 33  absolute_error               log2                 25
# 34  absolute_error               log2                 50
# 35  absolute_error               log2                100
# 36         poisson               None                 10
# 37         poisson               None                 25
# 38         poisson               None                 50
# 39         poisson               None                100
# 40         poisson               sqrt                 10
# 41         poisson               sqrt                 25
# 42         poisson               sqrt                 50
# 43         poisson               sqrt                100
# 44         poisson               log2                 10
# 45         poisson               log2                 25
# 46         poisson               log2                 50
# 47         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.836774
# 1   {'criterion': 'squared_error', 'max_features':...           0.846669
# 2   {'criterion': 'squared_error', 'max_features':...           0.845393
# 3   {'criterion': 'squared_error', 'max_features':...           0.844789
# 4   {'criterion': 'squared_error', 'max_features':...           0.848989
# 5   {'criterion': 'squared_error', 'max_features':...           0.849320
# 6   {'criterion': 'squared_error', 'max_features':...           0.854378
# 7   {'criterion': 'squared_error', 'max_features':...           0.858187
# 8   {'criterion': 'squared_error', 'max_features':...           0.833720
# 9   {'criterion': 'squared_error', 'max_features':...           0.852051
# 10  {'criterion': 'squared_error', 'max_features':...           0.855197
# 11  {'criterion': 'squared_error', 'max_features':...           0.856900
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.837607
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.850450
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.847365
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.847984
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.849287
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.851849
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.851646
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.858018
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.843129
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.857295
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.853594
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.860909
# 24  {'criterion': 'absolute_error', 'max_features'...           0.806720
# 25  {'criterion': 'absolute_error', 'max_features'...           0.840525
# 26  {'criterion': 'absolute_error', 'max_features'...           0.836028
# 27  {'criterion': 'absolute_error', 'max_features'...           0.839981
# 28  {'criterion': 'absolute_error', 'max_features'...           0.846766
# 29  {'criterion': 'absolute_error', 'max_features'...           0.860105
# 30  {'criterion': 'absolute_error', 'max_features'...           0.849237
# 31  {'criterion': 'absolute_error', 'max_features'...           0.856012
# 32  {'criterion': 'absolute_error', 'max_features'...           0.844932
# 33  {'criterion': 'absolute_error', 'max_features'...           0.856316
# 34  {'criterion': 'absolute_error', 'max_features'...           0.859646
# 35  {'criterion': 'absolute_error', 'max_features'...           0.853234
# 36  {'criterion': 'poisson', 'max_features': None,...           0.827474
# 37  {'criterion': 'poisson', 'max_features': None,...           0.847321
# 38  {'criterion': 'poisson', 'max_features': None,...           0.843746
# 39  {'criterion': 'poisson', 'max_features': None,...           0.847681
# 40  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839318
# 41  {'criterion': 'poisson', 'max_features': 'sqrt...           0.850046
# 42  {'criterion': 'poisson', 'max_features': 'sqrt...           0.851055
# 43  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860843
# 44  {'criterion': 'poisson', 'max_features': 'log2...           0.849449
# 45  {'criterion': 'poisson', 'max_features': 'log2...           0.858424
# 46  {'criterion': 'poisson', 'max_features': 'log2...           0.853031
# 47  {'criterion': 'poisson', 'max_features': 'log2...           0.860503
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.759124           0.853801           0.811425
# 1            0.770341           0.849372           0.819636
# 2            0.774282           0.858889           0.824486
# 3            0.770551           0.854026           0.820111
# 4            0.757344           0.859110           0.813995
# 5            0.770072           0.851406           0.826099
# 6            0.775455           0.863571           0.827703
# 7            0.782591           0.867186           0.828353
# 8            0.774619           0.844316           0.824328
# 9            0.779324           0.850303           0.826261
# 10           0.778438           0.854908           0.823326
# 11           0.775731           0.864633           0.826552
# 12           0.767686           0.819453           0.802416
# 13           0.763450           0.862362           0.815334
# 14           0.768930           0.854264           0.817890
# 15           0.776275           0.863315           0.817046
# 16           0.764713           0.852304           0.807320
# 17           0.761624           0.840373           0.820051
# 18           0.775972           0.856698           0.824464
# 19           0.779745           0.858981           0.828772
# 20           0.761874           0.854374           0.815354
# 21           0.766716           0.863584           0.823140
# 22           0.780810           0.858710           0.827901
# 23           0.778123           0.858881           0.826397
# 24           0.772477           0.840703           0.817996
# 25           0.763323           0.832961           0.831080
# 26           0.772716           0.841846           0.822874
# 27           0.771640           0.850393           0.826296
# 28           0.763117           0.825367           0.810147
# 29           0.777682           0.840181           0.822500
# 30           0.772462           0.858687           0.828003
# 31           0.779997           0.853585           0.828950
# 32           0.756717           0.841959           0.821273
# 33           0.783567           0.856390           0.824434
# 34           0.783943           0.853436           0.833610
# 35           0.775450           0.858044           0.830860
# 36           0.771156           0.846575           0.814734
# 37           0.769920           0.862539           0.808100
# 38           0.771589           0.851818           0.822683
# 39           0.775343           0.860841           0.815083
# 40           0.763870           0.844352           0.821926
# 41           0.775879           0.861685           0.815496
# 42           0.778347           0.860505           0.830463
# 43           0.779218           0.859294           0.827475
# 44           0.763143           0.836148           0.809214
# 45           0.770203           0.854504           0.814015
# 46           0.778806           0.858671           0.822231
# 47           0.778712           0.859357           0.828352
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.822446         0.816714        0.032110               44
# 1            0.832652         0.823734        0.028742               32
# 2            0.836494         0.827909        0.029075               21
# 3            0.839315         0.825758        0.029748               26
# 4            0.834906         0.822869        0.036091               34
# 5            0.828831         0.825146        0.029400               30
# 6            0.839815         0.832184        0.030901               11
# 7            0.836687         0.834601        0.029552                1
# 8            0.812371         0.817871        0.024055               43
# 9            0.833203         0.828228        0.026363               20
# 10           0.835904         0.829555        0.028257               16
# 11           0.838347         0.832432        0.031369                9
# 12           0.834342         0.812301        0.025556               48
# 13           0.835260         0.825371        0.034728               28
# 14           0.829345         0.823559        0.030198               33
# 15           0.834436         0.827811        0.029944               22
# 16           0.829430         0.820611        0.032267               40
# 17           0.836183         0.822016        0.031871               36
# 18           0.836969         0.829150        0.028900               17
# 19           0.843854         0.833874        0.029219                3
# 20           0.829223         0.820791        0.032245               39
# 21           0.834309         0.829009        0.034463               18
# 22           0.840815         0.832366        0.027907               10
# 23           0.838983         0.832659        0.030130                6
# 24           0.824612         0.812502        0.022837               47
# 25           0.842879         0.822153        0.029747               35
# 26           0.831322         0.820957        0.024907               38
# 27           0.838805         0.825423        0.027957               27
# 28           0.828855         0.814850        0.028368               45
# 29           0.837758         0.827645        0.027698               23
# 30           0.843665         0.830411        0.030638               14
# 31           0.843666         0.832442        0.027897                8
# 32           0.842472         0.821471        0.033479               37
# 33           0.835654         0.831272        0.026832               13
# 34           0.839892         0.834105        0.026743                2
# 35           0.845515         0.832620        0.030030                7
# 36           0.830366         0.818061        0.025551               41
# 37           0.836466         0.824869        0.032736               31
# 38           0.836594         0.825286        0.028505               29
# 39           0.838960         0.827582        0.030082               24
# 40           0.802627         0.814419        0.029212               46
# 41           0.839857         0.828593        0.030439               19
# 42           0.839378         0.831950        0.028674               12
# 43           0.840732         0.833512        0.029827                4
# 44           0.832069         0.818005        0.030341               42
# 45           0.836809         0.826791        0.032356               25
# 46           0.835351         0.829618        0.028501               15
# 47           0.839079         0.833201        0.029855                5

# %%
# Getting the inputs for future prediction

age_input = float(input('Age: '))
bmi_input = float(input('BMI: '))
children_input = float(input('Children: '))
sex_male_input = float(input('Sex Male 0 or 1: '))
smoker_yes_input = float(input('Smoker yes 0 or 1: '))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
# Evaluating and printing the Predicted value

Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future Prediction {} : ".format(Future_Prediction))
# Out:
# Future Prediction [45866.0823868] :
# C:\Users\reema\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
