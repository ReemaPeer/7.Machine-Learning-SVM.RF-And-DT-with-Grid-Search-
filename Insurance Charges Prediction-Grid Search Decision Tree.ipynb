# %%
# Importing Libraries

import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# Reading the Dataset

dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Converting the nominal data to numeric data

dataset = pd.get_dummies(dataset, drop_first = True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# Getting the column names

dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# Splitting the dataset into input and output variables

independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#Importing GridSearchCv and DecissiontreeRegressor to create the best model 

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion' :['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
              'max_features' : [None, 'sqrt', 'log2'], 'splitter' : ['best', 'random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1 )
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# Printing the best model from the grid

re = grid.cv_results_

print("The R_Score for Best parameter is {} : ".format(grid.best_params_))
# Out:
# The R_Score for Best parameter is {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'} :

# %%
# getting all the grid values in table format

table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.026785      0.006640         0.004832        0.001457
# 1        0.017419      0.007535         0.003083        0.002781
# 2        0.011708      0.001355         0.004537        0.002530
# 3        0.007654      0.004525         0.006059        0.004075
# 4        0.007432      0.006068         0.000000        0.000000
# 5        0.006298      0.007713         0.008331        0.006331
# 6        0.014885      0.007115         0.002168        0.004337
# 7        0.011124      0.010014         0.006397        0.007369
# 8        0.011399      0.005831         0.001753        0.003505
# 9        0.003505      0.004293         0.006005        0.007354
# 10       0.012010      0.006005         0.003807        0.004662
# 11       0.009410      0.005856         0.003441        0.004052
# 12       0.041842      0.004406         0.000000        0.000000
# 13       0.025069      0.008045         0.004200        0.006083
# 14       0.027501      0.004328         0.004507        0.005325
# 15       0.018117      0.006813         0.003127        0.006253
# 16       0.028048      0.006034         0.004733        0.006272
# 17       0.020370      0.009059         0.000467        0.000933
# 18       0.014109      0.003236         0.001286        0.002571
# 19       0.011944      0.006141         0.000702        0.001404
# 20       0.009307      0.005866         0.004801        0.006391
# 21       0.003829      0.006057         0.006385        0.007820
# 22       0.007021      0.007281         0.003127        0.006254
# 23       0.006368      0.007799         0.003929        0.006055
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.727831
# 1   {'criterion': 'squared_error', 'max_features':...           0.695700
# 2   {'criterion': 'squared_error', 'max_features':...           0.750878
# 3   {'criterion': 'squared_error', 'max_features':...           0.703072
# 4   {'criterion': 'squared_error', 'max_features':...           0.756563
# 5   {'criterion': 'squared_error', 'max_features':...           0.643489
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.726216
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.688316
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.716577
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.706308
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.715858
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.765745
# 12  {'criterion': 'absolute_error', 'max_features'...           0.721978
# 13  {'criterion': 'absolute_error', 'max_features'...           0.716236
# 14  {'criterion': 'absolute_error', 'max_features'...           0.689070
# 15  {'criterion': 'absolute_error', 'max_features'...           0.738231
# 16  {'criterion': 'absolute_error', 'max_features'...           0.712210
# 17  {'criterion': 'absolute_error', 'max_features'...           0.558111
# 18  {'criterion': 'poisson', 'max_features': None,...           0.746179
# 19  {'criterion': 'poisson', 'max_features': None,...           0.724817
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.675834
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.621705
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.752270
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.689787
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.652241           0.737099           0.736132
# 1            0.434101           0.724250           0.686801
# 2            0.614623           0.781401           0.650887
# 3            0.546293           0.632162           0.700369
# 4            0.636133           0.726019           0.603463
# 5            0.573429           0.662179           0.769912
# 6            0.644503           0.743626           0.705561
# 7            0.607168           0.642681           0.702317
# 8            0.655830           0.675704           0.681459
# 9            0.577462           0.731908           0.673332
# 10           0.600494           0.689072           0.711197
# 11           0.541604           0.721091           0.669021
# 12           0.634064           0.699838           0.734414
# 13           0.627176           0.754339           0.731536
# 14           0.620290           0.658071           0.700083
# 15           0.623773           0.671861           0.731527
# 16           0.554830           0.731655           0.713988
# 17           0.602962           0.767107           0.636537
# 18           0.662215           0.762049           0.728234
# 19           0.655083           0.764391           0.699360
# 20           0.497206           0.662075           0.739406
# 21           0.576529           0.777965           0.768267
# 22           0.661464           0.736548           0.742734
# 23           0.566317           0.701349           0.488719
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.674450         0.705551        0.035316                6
# 1            0.713950         0.650960        0.109227               21
# 2            0.696007         0.698759        0.061521                7
# 3            0.745779         0.665535        0.069849               17
# 4            0.656255         0.675687        0.056978               12
# 5            0.624497         0.654701        0.064765               19
# 6            0.673073         0.698596        0.035823                8
# 7            0.694817         0.667060        0.036460               15
# 8            0.760613         0.698037        0.036917                9
# 9            0.671740         0.672150        0.052355               13
# 10           0.591902         0.661704        0.054314               18
# 11           0.572358         0.653964        0.085454               20
# 12           0.757564         0.709571        0.042120                5
# 13           0.791622         0.724182        0.054745                1
# 14           0.666619         0.666827        0.027724               16
# 15           0.591919         0.671462        0.057736               14
# 16           0.705279         0.683593        0.064966               10
# 17           0.633696         0.639683        0.069692               23
# 18           0.702470         0.720229        0.035121                3
# 19           0.721803         0.713091        0.035773                4
# 20           0.652372         0.645379        0.080064               22
# 21           0.657504         0.680394        0.079998               11
# 22           0.717652         0.722133        0.032376                2
# 23           0.624108         0.614056        0.079303               24

# %%
# Getting the inputs for future prediction

age_input = float(input('Age: '))
bmi_input = float(input('BMI: '))
children_input = float(input('Children: '))
sex_male_input = float(input('Sex Male 0 or 1: '))
smoker_yes_input = float(input('Smoker yes 0 or 1: '))
# Out:
# Age: 32
# BMI: 43
# Children: 2
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
# Evaluating and printing the Predicted value

Future_Prediction = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future Prediction {} : ".format(Future_Prediction))
# Out:
# Future Prediction [43896.3763] :
# C:\Users\reema\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
